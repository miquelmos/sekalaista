# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
plt.style.use('ggplot')
# %matplotlib inline

# %%
iris = load_iris()

# %%
y = iris.target
X = iris.data

# %%
df = pd.DataFrame(data=X,columns=iris.feature_names)
y = pd.Series(y, name='target')
frames = [df,y]

# %%
df = pd.concat(frames, axis=1, names=names)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
plt.figure(figsize=(12,8))
#df.plot.scatter(x='sepal length (cm)',y='sepal width (cm)')
plt.scatter(x=df['sepal length (cm)'],y=df['sepal width (cm)'],c=df['target'])
plt.xlabel('sepal length')
plt.ylabel('sepal width')
# Out:
# Text(0,0.5,'sepal width')

# %%
plt.figure(figsize=(12,8))
#df.plot.scatter(x='sepal length (cm)',y='sepal width (cm)')
plt.scatter(x=df['petal length (cm)'],y=df['petal width (cm)'],c=df['target'])
plt.xlabel('petal length')
plt.ylabel('petal width')
# Out:
# Text(0,0.5,'petal width')

# %%
plt.figure(figsize=(12,8))
#df.plot.scatter(x='sepal length (cm)',y='sepal width (cm)')
plt.scatter(x=df['petal length (cm)']*df['sepal length (cm)'],y=df['petal width (cm)']*df['sepal width (cm)'],c=df['target'])
plt.xlabel('petal length * sepal length')
plt.ylabel('petal width * sepal width')
# Out:
# Text(0,0.5,'petal width * sepal width')

# %%
X = df.drop('target', axis=1)
y = df.target

# %%
from sklearn.cross_validation import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=35)

# %% [markdown]
# # KNN - Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
classifier = KNeighborsClassifier(n_neighbors=5)

# %%
classifier.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
preds = classifier.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(preds, y_test))
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        11
#           1       0.90      1.00      0.95         9
#           2       1.00      0.90      0.95        10
#
# avg / total       0.97      0.97      0.97        30

# %%
classifier.score(X_test,y_test)
# Out:
# 0.9666666666666667
